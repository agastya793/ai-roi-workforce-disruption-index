# %% [markdown]
# # 01 Data Collection Sec Edgar
#
# This notebook is part of the AI ROI & Workforce Disruption Index analysis pipeline.

# %%
import pandas as pd
import numpy as np
import os
import sys
sys.path.append('..')
